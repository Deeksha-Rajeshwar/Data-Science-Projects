# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
df1=pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv')
df1
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
## Task 1
df1.shape
# Out:
# (4803, 20)

# %%
df1[['original_title']].head(50)
# Out:
#                                  original_title
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# 18                               Men in Black 3
# ...

# %%
import json
df2=df1.copy()
columns_dict=['genres','production_companies']

# %%
for column in columns_dict:
    df2[column]=df2[column].apply(lambda x: [item['name'] for item in json.loads(x)])

# %%
df2
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4798     220000                      [Action, Crime, Thriller]
# 4799       9000                              [Comedy, Romance]
# 4800          0             [Comedy, Drama, Romance, TV Movie]
# 4801          0                                             []
# 4802          0                                  [Documentary]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
df2['company_first_index'] = df2['production_companies'].apply(lambda x: x[0] if x else None)

# %%
df2[['company_first_index']]
# Out:
#            company_first_index
# 0      Ingenious Film Partners
# 1         Walt Disney Pictures
# 2            Columbia Pictures
# 3           Legendary Pictures
# 4         Walt Disney Pictures
# ...                        ...
# 4798         Columbia Pictures
# 4799                      None
# 4800     Front Street Pictures
# 4801                      None
# 4802  rusty bear entertainment
#
# [4803 rows x 1 columns]

# %%
df2['genre_first_index'] = df2['genres'].apply(lambda x: x[0] if x else None)

# %%
df2[['genre_first_index']]
# Out:
#      genre_first_index
# 0               Action
# 1            Adventure
# 2               Action
# 3               Action
# 4               Action
# ...                ...
# 4798            Action
# 4799            Comedy
# 4800            Comedy
# 4801              None
# 4802       Documentary
#
# [4803 rows x 1 columns]

# %%
df2[['title','genre_first_index']].head(50)
# Out:
#                                           title genre_first_index
# 0                                        Avatar            Action
# 1      Pirates of the Caribbean: At World's End         Adventure
# 2                                       Spectre            Action
# 3                         The Dark Knight Rises            Action
# 4                                   John Carter            Action
# 5                                  Spider-Man 3           Fantasy
# 6                                       Tangled         Animation
# 7                       Avengers: Age of Ultron            Action
# 8        Harry Potter and the Half-Blood Prince         Adventure
# 9            Batman v Superman: Dawn of Justice            Action
# 10                             Superman Returns         Adventure
# 11                            Quantum of Solace         Adventure
# 12   Pirates of the Caribbean: Dead Man's Chest         Adventure
# ...

# %%
## Task 2
df1.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
## Task 3
df2[df2['budget'] > 220000][['genre_first_index']]
# Out:
#      genre_first_index
# 0               Action
# 1            Adventure
# 2               Action
# 3               Action
# 4               Action
# ...                ...
# 4680             Crime
# 4682            Horror
# 4720             Drama
# 4758          Thriller
# 4770             Drama
#
# [3684 rows x 1 columns]

# %%
## Task 4
df2[df2['revenue'] > 961000000][['genre_first_index']]
# Out:
#     genre_first_index
# 0              Action
# 3              Action
# 7              Action
# 12          Adventure
# 16    Science Fiction
# 17          Adventure
# 25              Drama
# 26          Adventure
# 28             Action
# 29             Action
# 31             Action
# 32             Family
# 36    Science Fiction
# 42          Animation
# 44             Action
# 52             Action
# 65              Drama
# 98          Adventure
# 124         Animation
# 197         Adventure
# 329         Adventure
# 506         Animation
# 546            Family

# %%
## Task 5
df2=df2[(df2['budget'] != 0) & (df2['revenue']!= 0)]
df2
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4773      27000                                       [Comedy]
# 4788      12000                        [Horror, Comedy, Crime]
# 4792      20000             [Crime, Horror, Mystery, Thriller]
# 4796       7000             [Science Fiction, Drama, Thriller]
# 4798     220000                      [Action, Crime, Thriller]
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
## Task 6
df2[['title','revenue']].sort_values(by='revenue',ascending=False).head(10)
# Out:
#                           title     revenue
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 124                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 546                     Minions  1156730962
# 26   Captain America: Civil War  1153304495

# %%
df2[['title','budget']].sort_values(by='budget').head(10)
# Out:
#                    title  budget
# 4238        Modern Times       1
# 3611  A Farewell to Arms       4
# 3372        Split Second       7
# 3419        Bran Nue Dae       7
# 4608        The Prophecy       8
# 3131   Of Horses and Men      10
# 3137           Nurse 3-D      10
# 2933            F.I.S.T.      11
# 1912      Angela's Ashes      25
# 1771      The 51st State      28

# %%
df2['budget_sum'] = df2['budget'].sum()

# %%
##Task 7
sb.regplot(x= "budget", 
            y = "popularity", 
            data = df1)
plt.xlabel('Budget')
plt.ylabel('Popularity')
plt.title('Popularity VS Budget for Movies')
plt.show()

# %%
## The points are scattered all over the plot, and there is no clear pattern or trend.
## This suggests that there is no relationship between the two variables.

# %%
## Task 8
df2.groupby('company_first_index')['company_first_index'].count().sort_values(ascending=False)
# Out:
# company_first_index
# Paramount Pictures                        241
# Universal Pictures                        228
# Columbia Pictures                         166
# Twentieth Century Fox Film Corporation    159
# New Line Cinema                           135
#                                          ...
# Lonely Film Productions GmbH & Co. KG.      1
# Loew's Incorporated                         1
# Code Entertainment                          1
# Columbia Pictures Industries                1
# icon                                        1
# Name: company_first_index, Length: 753, dtype: int64

# %%
## Task 9
pd.pivot_table(data=df2,index='company_first_index',values='title',aggfunc='count').sort_values(by=['title'], ascending=False).head(25)
# Out:
#                                         title
# company_first_index
# Paramount Pictures                        241
# Universal Pictures                        228
# Columbia Pictures                         166
# Twentieth Century Fox Film Corporation    159
# New Line Cinema                           135
# Walt Disney Pictures                       96
# Village Roadshow Pictures                  64
# United Artists                             61
# Miramax Films                              61
# Columbia Pictures Corporation              58
# Warner Bros.                               54
# DreamWorks SKG                             54
# Fox Searchlight Pictures                   46
# Summit Entertainment                       40
# TriStar Pictures                           36
# Metro-Goldwyn-Mayer (MGM)                  33
# The Weinstein Company                      27
# Lionsgate                                  27
# Regency Enterprises                        26
# ...

# %%
## Task 10
df2 = df2.sort_values(by='revenue', ascending=False) 
top_500 = df2.head(500) 
top_500
# Out:
#          budget                                          genres  \
# 0     237000000   [Action, Adventure, Fantasy, Science Fiction]
# 25    200000000                      [Drama, Romance, Thriller]
# 16    220000000            [Science Fiction, Action, Adventure]
# 28    150000000  [Action, Adventure, Science Fiction, Thriller]
# 44    190000000                                        [Action]
# ...         ...                                             ...
# 397    85000000                               [Comedy, Romance]
# 1744   30000000                        [Comedy, Romance, Drama]
# 698    70000000    [Adventure, Animation, Drama, Family, Music]
# 717    60000000                        [Crime, Drama, Thriller]
# 714    65000000                        [Drama, Crime, Thriller]
#
#                                homepage      id  \
# 0           http://www.avatarmovie.com/   19995
# 25          http://www.titanicmovie.com     597
# 16    http://marvel.com/avengers_movie/   24428
# ...

# %%
top_500[['budget','runtime','revenue']].describe()
# Out:
#              budget     runtime       revenue
# count  5.000000e+02  500.000000  5.000000e+02
# mean   1.031937e+08  118.720000  4.585776e+08
# std    6.224893e+07   23.257158  2.685357e+08
# min    6.000000e+04   70.000000  2.177643e+08
# 25%    5.500000e+07  100.000000  2.814473e+08
# 50%    9.500000e+07  116.000000  3.630016e+08
# 75%    1.500000e+08  132.000000  5.471332e+08
# max    3.800000e+08  238.000000  2.787965e+09

# %%
avg_runtime=top_500['runtime'].mean()
avg_runtime
# Out:
# 108.912

# %%
print('Mean:',top_500['budget'].mean())
print('Median:',top_500['budget'].median())
print('Mode',top_500['budget'].mode()[0])
# Out:
# Mean: 103193736.0
# Median: 95000000.0
# Mode 150000000

# %%
print('Mean:',top_500['revenue'].mean())
print('Median:',top_500['revenue'].median())
print('Mode',top_500['revenue'].mode()[0])
# Out:
# Mean: 458577595.062
# Median: 363001569.5
# Mode 217764291

# %%
print('Mean:',top_500['runtime'].mean())
print('Median:',top_500['runtime'].median())
print('Mode',top_500['runtime'].mode()[0])
# Out:
# Mean: 118.72
# Median: 116.0
# Mode 115.0

# %%
## Outlier Analysis
plt.figure(figsize=(15,4))
plt.subplot(131)
top_500['runtime'].plot(kind='box',vert=0,showmeans=True);
plt.subplot(132)
top_500['budget'].plot(kind='box',vert=0,showmeans=True);
plt.subplot(133)
top_500['revenue'].plot(kind='box',vert=0,showmeans=True);

# %%
 ## Task 11
above_avg_movies = df[df['runtime'] > avg_runtime]
production_counts = above_avg_movies[['title','runtime']]
production_counts
# Out:
#                            title  runtime
# 0                         Avatar    162.0
# 25                       Titanic    194.0
# 16                  The Avengers    143.0
# 28                Jurassic World    124.0
# 44                     Furious 7    137.0
# ...                          ...      ...
# 1161          The Social Network    120.0
# 912   Interview with the Vampire    123.0
# 521                 The Terminal    128.0
# 397             It's Complicated    121.0
# 1744                  Knocked Up    129.0
#
# [232 rows x 2 columns]
